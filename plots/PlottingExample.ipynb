# %% [markdown]
# # OVERT Plots with Julia Extension System
#
# To enhance compatibility of OVERT with other packages, the plotting libraries are note loaded by default.
# Instead, using OVERT's plotting capabilities requires the explicit loading (and then activation of) plotting:

# %%
using OVERT

# %% [markdown]
# By default OVERT produces no plots:

# %%
func = :(sin(x + y) * exp(z))
range_dict = Dict(:x => [1., 2.], :y => [-1., 1.], :z => [0., 1.])
o1 = overapprox(func, range_dict)
# Out:
# Using N=2, ϵ=0.0001, rel_error_tol=0.005
# output = v_24
# v_1 == x + y
# v_2 == 0.00010059581907858486 * max(0, -1.0061081012321205 * (v_1 - 0.9939289811655027)) + 0.9940295769785069 * max(0, min(1.0061081012321205 * (v_1 - 0.0), -0.8830096335143647 * (v_1 - 2.1264194569715427))) + 1.006058786604927 * max(0, min(0.8830096335143647 * (v_1 - 0.9939289811655027), -1.1447141399615908 * (v_1 - 3.0))) + 0.1412206038789458 * max(0, 1.1447141399615908 * (v_1 - 2.1264194569715427))
# v_3 == -9.219221342306769e-5 * max(0, -0.9230119824482484 * (v_1 - 1.083409553738993)) + 0.8834675045444836 * max(0, min(0.9230119824482484 * (v_1 - 0.0), -1.1297269937790038 * (v_1 - 1.9685791615350683))) + 0.9218299420172538 * max(0, min(1.1297269937790038 * (v_1 - 1.083409553738993), -0.9695363548096474 * (v_1 - 3.0))) + 0.14102781584644414 * max(0, 0.9695363548096474 * (v_1 - 1.9685791615350683))
# v_5 == 1.000171828182846 * max(0, -2.691439160963136 * (z - 0.3715484319705552)) + 1.4501498978788931 * max(0, min(2.691439160963136 * (z - 0.0), -3.0245447896058826 * (z - 0.7021766982262209))) + 2.0183126416584236 * max(0, min(3.0245447896058826 * (z - 0.3715484319705552), -3.35769563376737 * (z - 1.0))) + 2.718453656641891 * max(0, 3.35769563376737 * (z - 0.7021766982262209))
# v_6 == 0.9998281718171541 * max(0, -3.3871859271361773 * (z - 0.29523032437888264)) + 1.2950584915150136 * max(0, min(3.3871859271361773 * (z - 0.0), -2.028007026560982 * (z - 0.7883252628593288))) + 2.1427184087655933 * max(0, min(2.028007026560982 * (z - 0.29523032437888264), -4.724229322346752 * (z - 1.0))) + 2.7181100002761993 * max(0, 4.724229322346752 * (z - 0.7883252628593288))
# v_8 == (v_4 - -9.219221342306769e-5) / 1.0061509788183503 + 0.1
# v_9 == (v_7 - 0.9998281718171541) / 1.7186254848247366 + 0.1
# v_10 == -2.302345303466766 * max(0, -11.258981929061719 * (v_8 - 0.18881797717596446)) + -1.4141655306212193 * max(0, min(11.258981929061719 * (v_8 - 0.1), -2.1378841011415037 * (v_8 - 0.6565701810798427))) + -0.3075680478743538 * max(0, min(2.1378841011415037 * (v_8 - 0.18881797717596446), -2.2551482947971455 * (v_8 - 1.1))) + 0.09554996933160477 * max(0, 2.2551482947971455 * (v_8 - 0.6565701810798427))
# v_11 == -2.302824882521325 * max(0, -5.603462662982342 * (v_8 - 0.27846108025421695)) + -1.2787167666483967 * max(0, min(5.603462662982342 * (v_8 - 0.1), -3.129408004988966 * (v_8 - 0.5980103363453945))) + -0.5143870298496475 * max(0, min(3.129408004988966 * (v_8 - 0.27846108025421695), -1.992072889947094 * (v_8 - 1.1))) + 0.0950703902770451 * max(0, 1.992072889947094 * (v_8 - 0.5980103363453945))
# v_13 == -2.302345303466766 * max(0, -11.258981929061719 * (v_9 - 0.18881797717596446)) + -1.4141655306212193 * max(0, min(11.258981929061719 * (v_9 - 0.1), -2.1378841011415037 * (v_9 - 0.6565701810798427))) + -0.3075680478743538 * max(0, min(2.1378841011415037 * (v_9 - 0.18881797717596446), -2.2551482947971455 * (v_9 - 1.1))) + 0.09554996933160477 * max(0, 2.2551482947971455 * (v_9 - 0.6565701810798427))
# v_14 == -2.302824882521325 * max(0, -5.603462662982342 * (v_9 - 0.27846108025421695)) + -1.2787167666483967 * max(0, min(5.603462662982342 * (v_9 - 0.1), -3.129408004988966 * (v_9 - 0.5980103363453945))) + -0.5143870298496475 * max(0, min(3.129408004988966 * (v_9 - 0.27846108025421695), -1.992072889947094 * (v_9 - 1.1))) + 0.0950703902770451 * max(0, 1.992072889947094 * (v_9 - 0.5980103363453945))
# v_16 == v_12 + v_15
# v_17 == 0.010115263881697608 * max(0, -0.40267901145189294 * (v_16 - -2.1222821904714895)) + 0.11987806434334698 * max(0, min(0.40267901145189294 * (v_16 - -4.60564976504265), -0.7296588226779495 * (v_16 - -0.7517786497483598))) + 0.47164718335871153 * max(0, min(0.7296588226779495 * (v_16 - -2.1222821904714895), -1.0605819373676317 * (v_16 - 0.19109993866320954))) + 1.2107004883483328 * max(0, 1.0605819373676317 * (v_16 - -0.7517786497483598))
# v_18 == 0.009875146836804282 * max(0, -0.4020489629044491 * (v_16 - -2.118390519860466)) + 0.03473581376900499 * max(0, min(0.4020489629044491 * (v_16 - -4.60564976504265), -0.5683688257688495 * (v_16 - -0.3589696039661607))) + 0.5445569479553188 * max(0, min(0.5683688257688495 * (v_16 - -2.118390519860466), -1.8179519542564222 * (v_16 - 0.19109993866320954))) + 1.2104603713034396 * max(0, 1.8179519542564222 * (v_16 - -0.3589696039661607))
# v_20 == 1.7291967137785704v_19
# v_21 == 0.8330584223461341v_8
# v_22 == v_20 + v_21
# v_23 == -0.17307811526534836v_9 + -0.08338217421806686
# v_24 == v_22 + v_23
# v_3 ≦ v_4
# v_4 ≦ v_2
# v_6 ≦ v_7
# v_7 ≦ v_5
# v_11 ≦ v_12
# v_12 ≦ v_10
# v_14 ≦ v_15
# v_15 ≦ v_13
# v_18 ≦ v_19
# v_19 ≦ v_17
# [-0.17338618731705385, 2.9092135846581937]

# %% [markdown]
# Because we have not loaded the plotting libraries, this call fails:

# %%
OVERT.set_plotflag(true)
# Out:
# PlotExt.jl is not activated.
#
#                    To activate it please import LaTeXStrings, PGFPlots, PlotlyBase, and Plots.
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] set_plotflag(bool::Bool)
#
#    @ OVERT ~/Dokumente/Projects/NNV/NCubeV/repos/OVERT.jl/src/overapprox_nd.jl:21
#
#  [3] top-level scope
#
#    @ ~/Dokumente/Projects/NNV/NCubeV/repos/OVERT.jl/plots/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1

# %% [markdown]
# If we have installed them, we can now load these plotting libraries:

# %%
# Requires environment with those installed:
using LaTeXStrings, PGFPlots, Plots, PlotlyBase

# %% [markdown]
# This allows us to activate plotting:

# %%
OVERT.set_plotflag(true)
# Out:
# true

# %% [markdown]
# Create folder for plots...

# %%
mkdir("plots")
# Out:
# "plots"

# %% [markdown]
# Now overapproximation will generate plots:

# %%
func = :(sin(x + y) * exp(z))
range_dict = Dict(:x => [1., 2.], :y => [-1., 1.], :z => [0., 1.])
o1 = overapprox(func, range_dict)
# Out:
# Using N=2, ϵ=0.0001, rel_error_tol=0.005
# funstring = sin
# Saving PGF plot
# funstring = exp
# Saving PGF plot
# funstring = log
# Saving PGF plot
# funstring = log
# Saving PGF plot
# funstring = exp
# Saving PGF plot
# output = v_73
# v_50 == x + y
# v_51 == 0.00010059581907858486 * max(0, -1.0061081012321205 * (v_50 - 0.9939289811655027)) + 0.9940295769785069 * max(0, min(1.0061081012321205 * (v_50 - 0.0), -0.8830096335143647 * (v_50 - 2.1264194569715427))) + 1.006058786604927 * max(0, min(0.8830096335143647 * (v_50 - 0.9939289811655027), -1.1447141399615908 * (v_50 - 3.0))) + 0.1412206038789458 * max(0, 1.1447141399615908 * (v_50 - 2.1264194569715427))
# v_52 == -9.219221342306769e-5 * max(0, -0.9230119824482484 * (v_50 - 1.083409553738993)) + 0.8834675045444836 * max(0, min(0.9230119824482484 * (v_50 - 0.0), -1.1297269937790038 * (v_50 - 1.9685791615350683))) + 0.9218299420172538 * max(0, min(1.1297269937790038 * (v_50 - 1.083409553738993), -0.9695363548096474 * (v_50 - 3.0))) + 0.14102781584644414 * max(0, 0.9695363548096474 * (v_50 - 1.9685791615350683))
# v_54 == 1.000171828182846 * max(0, -2.691439160963136 * (z - 0.3715484319705552)) + 1.4501498978788931 * max(0, min(2.691439160963136 * (z - 0.0), -3.0245447896058826 * (z - 0.7021766982262209))) + 2.0183126416584236 * max(0, min(3.0245447896058826 * (z - 0.3715484319705552), -3.35769563376737 * (z - 1.0))) + 2.718453656641891 * max(0, 3.35769563376737 * (z - 0.7021766982262209))
# v_55 == 0.9998281718171541 * max(0, -3.3871859271361773 * (z - 0.29523032437888264)) + 1.2950584915150136 * max(0, min(3.3871859271361773 * (z - 0.0), -2.028007026560982 * (z - 0.7883252628593288))) + 2.1427184087655933 * max(0, min(2.028007026560982 * (z - 0.29523032437888264), -4.724229322346752 * (z - 1.0))) + 2.7181100002761993 * max(0, 4.724229322346752 * (z - 0.7883252628593288))
# v_57 == (v_53 - -9.219221342306769e-5) / 1.0061509788183503 + 0.1
# v_58 == (v_56 - 0.9998281718171541) / 1.7186254848247366 + 0.1
# v_59 == -2.302345303466766 * max(0, -11.258981929061719 * (v_57 - 0.18881797717596446)) + -1.4141655306212193 * max(0, min(11.258981929061719 * (v_57 - 0.1), -2.1378841011415037 * (v_57 - 0.6565701810798427))) + -0.3075680478743538 * max(0, min(2.1378841011415037 * (v_57 - 0.18881797717596446), -2.2551482947971455 * (v_57 - 1.1))) + 0.09554996933160477 * max(0, 2.2551482947971455 * (v_57 - 0.6565701810798427))
# v_60 == -2.302824882521325 * max(0, -5.603462662982342 * (v_57 - 0.27846108025421695)) + -1.2787167666483967 * max(0, min(5.603462662982342 * (v_57 - 0.1), -3.129408004988966 * (v_57 - 0.5980103363453945))) + -0.5143870298496475 * max(0, min(3.129408004988966 * (v_57 - 0.27846108025421695), -1.992072889947094 * (v_57 - 1.1))) + 0.0950703902770451 * max(0, 1.992072889947094 * (v_57 - 0.5980103363453945))
# v_62 == -2.302345303466766 * max(0, -11.258981929061719 * (v_58 - 0.18881797717596446)) + -1.4141655306212193 * max(0, min(11.258981929061719 * (v_58 - 0.1), -2.1378841011415037 * (v_58 - 0.6565701810798427))) + -0.3075680478743538 * max(0, min(2.1378841011415037 * (v_58 - 0.18881797717596446), -2.2551482947971455 * (v_58 - 1.1))) + 0.09554996933160477 * max(0, 2.2551482947971455 * (v_58 - 0.6565701810798427))
# v_63 == -2.302824882521325 * max(0, -5.603462662982342 * (v_58 - 0.27846108025421695)) + -1.2787167666483967 * max(0, min(5.603462662982342 * (v_58 - 0.1), -3.129408004988966 * (v_58 - 0.5980103363453945))) + -0.5143870298496475 * max(0, min(3.129408004988966 * (v_58 - 0.27846108025421695), -1.992072889947094 * (v_58 - 1.1))) + 0.0950703902770451 * max(0, 1.992072889947094 * (v_58 - 0.5980103363453945))
# v_65 == v_61 + v_64
# v_66 == 0.010115263881697608 * max(0, -0.40267901145189294 * (v_65 - -2.1222821904714895)) + 0.11987806434334698 * max(0, min(0.40267901145189294 * (v_65 - -4.60564976504265), -0.7296588226779495 * (v_65 - -0.7517786497483598))) + 0.47164718335871153 * max(0, min(0.7296588226779495 * (v_65 - -2.1222821904714895), -1.0605819373676317 * (v_65 - 0.19109993866320954))) + 1.2107004883483328 * max(0, 1.0605819373676317 * (v_65 - -0.7517786497483598))
# v_67 == 0.009875146836804282 * max(0, -0.4020489629044491 * (v_65 - -2.118390519860466)) + 0.03473581376900499 * max(0, min(0.4020489629044491 * (v_65 - -4.60564976504265), -0.5683688257688495 * (v_65 - -0.3589696039661607))) + 0.5445569479553188 * max(0, min(0.5683688257688495 * (v_65 - -2.118390519860466), -1.8179519542564222 * (v_65 - 0.19109993866320954))) + 1.2104603713034396 * max(0, 1.8179519542564222 * (v_65 - -0.3589696039661607))
# v_69 == 1.7291967137785704v_68
# v_70 == 0.8330584223461341v_57
# v_71 == v_69 + v_70
# v_72 == -0.17307811526534836v_58 + -0.08338217421806686
# v_73 == v_71 + v_72
# v_52 ≦ v_53
# v_53 ≦ v_51
# v_55 ≦ v_56
# v_56 ≦ v_54
# v_60 ≦ v_61
# v_61 ≦ v_59
# v_63 ≦ v_64
# v_64 ≦ v_62
# v_67 ≦ v_68
# v_68 ≦ v_66
# [-0.17338618731705385, 2.9092135846581937]
